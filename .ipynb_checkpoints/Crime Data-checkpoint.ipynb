# %% [markdown]
# # <span style = 'color: #00adee'> Crime Data

# %% [markdown]
# People living in high crime areas can be at higher risk of substance miss-use. This is evident in areas of lower socio-economic status where there is an increased rate of unemployment, poor support systems and low rates of school retention.

# %%
import pandas as pd
import numpy as np
from IPython.display import IFrame

# %%
a = 'https://app.powerbi.com/reportEmbed?reportId=f3d4ac41-8cc8-48e0-9096-5b4d7b256b5b&autoAuth=true&ctid=282e8c9e-daf7-4f9e-a238-0330c86cc7a4&config=eyJjbHVzdGVyVXJsIjoiaHR0cHM6Ly93YWJpLWF1c3RyYWxpYS1zb3V0aGVhc3QtcmVkaXJlY3QuYW5hbHlzaXMud2luZG93cy5uZXQvIn0%3D'
IFrame(a, width = 1140, height = 541.25)
# Out:
#         <iframe
#             width="1140"
#             height="541.25"
#             src="https://app.powerbi.com/reportEmbed?reportId=f3d4ac41-8cc8-48e0-9096-5b4d7b256b5b&autoAuth=true&ctid=282e8c9e-daf7-4f9e-a238-0330c86cc7a4&config=eyJjbHVzdGVyVXJsIjoiaHR0cHM6Ly93YWJpLWF1c3RyYWxpYS1zb3V0aGVhc3QtcmVkaXJlY3QuYW5hbHlzaXMud2luZG93cy5uZXQvIn0%3D"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
import numpy as np
vemd_nov = pd.read_csv('C:/Users/Emma.Zhang/OneDrive - Melbourne Primary Care Network/Documents/Needs Assessment/AOD/PHN_2021_Nov/PHN_VEMD2021_Nov_20201217.txt', engine = 'python', delimiter='\t')

# %%
vemd_dec = pd.read_csv('C:/Users/Emma.Zhang/OneDrive - Melbourne Primary Care Network/Documents/Needs Assessment/AOD/PHN_2021_Dec/PHN_VEMD2021_Dec_20210119.txt', engine = 'python', delimiter='\t')
vemd_dec
# Out:
#          Fin_Yr MonthName                 Arrival_Time  campus_code  \
# 0       2020/21      July            Weekday_BusHrs_AM         1660
# 1       2020/21      July  Weekday_Unsociable_Early_AM         1660
# 2       2020/21      July  Weekday_Unsociable_Early_AM         1660
# 3       2020/21      July  Weekday_Unsociable_Early_AM         1660
# 4       2020/21      July  Weekday_Unsociable_Early_AM         1660
# ...         ...       ...                          ...          ...
# 792940  2020/21    August                    Sunday_AM         1334
# 792941  2020/21    August            Weekday_BusHrs_AM         1334
# 792942  2020/21    August                    Sunday_AM         1334
# 792943  2020/21    August   Weekday_Unsociable_Late_PM         1334
# 792944  2020/21    August            Weekday_BusHrs_PM         1334
#
#        did_not_wait  LOS_in_ED Trt_in_time  Time_to_treatment  \
# 0            Waited         86         Yes                6.0
# ...

# %%
data = pd.read_csv('C:/Users/Emma.Zhang/OneDrive - Melbourne Primary Care Network/Documents/Needs Assessment/AOD/PHN_2021_Dec/SA2_SA3_2016_AUST.csv')
data
# Out:
#       SA2_MAINCODE_2016  SA2_5DIGITCODE_2016  \
# 0             101021007                11007
# 1             101021008                11008
# 2             101021009                11009
# 3             101021010                11010
# 4             101021011                11011
# ...                 ...                  ...
# 2305          901021002                91002
# 2306          901031003                91003
# 2307          901041004                91004
# 2308          997979799                99799
# 2309          999999499                99499
#
#                              SA2_NAME_2016  SA3_CODE_2016  \
# 0                                Braidwood          10102
# 1                                  Karabar          10102
# 2                               Queanbeyan          10102
# 3                        Queanbeyan - East          10102
# 4                        Queanbeyan Region          10102
# ...                                    ...            ...
# ...

# %%
data = data[data['SA3_CODE_2016'].isin(SA3)]

# %%
data
# Out:
#      SA2_MAINCODE_2016  SA2_5DIGITCODE_2016       SA2_NAME_2016  \
# 682          206011105                21105           Brunswick
# 683          206011106                21106      Brunswick East
# 684          206011107                21107      Brunswick West
# 685          206011108                21108              Coburg
# 686          206011109                21109   Pascoe Vale South
# ..                 ...                  ...                 ...
# 970          213051464                21464   Point Cook - East
# 971          213051465                21465  Point Cook - North
# 972          213051466                21466  Point Cook - South
# 973          213051467                21467     Werribee - East
# 974          213051468                21468     Werribee - West
#
#      SA3_CODE_2016       SA3_NAME_2016  SA4_CODE_2016      SA4_NAME_2016  \
# 682          20601  Brunswick - Coburg            206  Melbourne - Inner
# ...

# %%
data.to_csv('SA2 and SA3 in NWMPHN.csv')

# %%
nwmphn = pd.read_excel('C:/Users/Emma.Zhang/OneDrive - Melbourne Primary Care Network/Documents/Needs Assessment/AOD/PHN_2021_Dec/SA3_2016_PHN_2017.xls', sheet_name='Table 3')

# %%
nwmphn
# Out:
#                        Australian Bureau of Statistics      Unnamed: 1  \
# 0    Statistical Area Level 3 2016 to Primary Healt...             NaN
# 1                                                  NaN             NaN
# 2                               Table 3 Correspondence             NaN
# 3                                                  NaN             NaN
# 4                                        SA3_CODE_2016   SA3_NAME_2016
# ..                                                 ...             ...
# 386                                              90103      Jervis Bay
# 387                                              90104  Norfolk Island
# 388                                                NaN             NaN
# 389                                                NaN             NaN
# 390                   © Commonwealth of Australia 2017             NaN
#
#         Unnamed: 2                  Unnamed: 3 Unnamed: 4  Unnamed: 5
# ...

# %%
nwmphn = nwmphn.dropna(subset=['Unnamed: 1'])

# %%
nwmphn
# Out:
#     Australian Bureau of Statistics               Unnamed: 1     Unnamed: 2  \
# 4                     SA3_CODE_2016            SA3_NAME_2016  PHN_CODE_2017
# 6                             10102               Queanbeyan         PHN106
# 7                             10103          Snowy Mountains         PHN106
# 8                             10104              South Coast         PHN106
# 9                             10105      Goulburn - Mulwaree         PHN105
# ..                              ...                      ...            ...
# 383                           80111       Urriarra - Namadgi         PHN801
# 384                           90101         Christmas Island         PHN502
# 385                           90102  Cocos (Keeling) Islands         PHN502
# 386                           90103               Jervis Bay         PHN106
# 387                           90104           Norfolk Island         PHN101
#
#                        Unnamed: 3 Unnamed: 4  Unnamed: 5
# ...

# %%
nwmphn.columns = nwmphn.iloc[0]

# %%
nwmphn=nwmphn.iloc[1:]

# %%
nwmphn
# Out:
# 4   SA3_CODE_2016            SA3_NAME_2016 PHN_CODE_2017  \
# 6           10102               Queanbeyan        PHN106
# 7           10103          Snowy Mountains        PHN106
# 8           10104              South Coast        PHN106
# 9           10105      Goulburn - Mulwaree        PHN105
# 10          10105      Goulburn - Mulwaree        PHN106
# ..            ...                      ...           ...
# 383         80111       Urriarra - Namadgi        PHN801
# 384         90101         Christmas Island        PHN502
# 385         90102  Cocos (Keeling) Islands        PHN502
# 386         90103               Jervis Bay        PHN106
# 387         90104           Norfolk Island        PHN101
#
# 4                   PHN_NAME_2017      RATIO PERCENTAGE
# 6               South Eastern NSW          1        100
# 7               South Eastern NSW          1        100
# 8               South Eastern NSW          1        100
# ...

# %%
nwmphn = nwmphn[nwmphn['PHN_CODE_2017'] == 'PHN201']

# %%
nwmphn
# Out:
# 4   SA3_CODE_2016               SA3_NAME_2016 PHN_CODE_2017  \
# 143         20601          Brunswick - Coburg        PHN201
# 144         20602             Darebin - South        PHN201
# 145         20603                    Essendon        PHN201
# 146         20604              Melbourne City        PHN201
# 149         20607                       Yarra        PHN201
# 158         20902             Darebin - North        PHN201
# 161         21001                      Keilor        PHN201
# 162         21002              Macedon Ranges        PHN201
# 163         21003            Moreland - North        PHN201
# 164         21004                     Sunbury        PHN201
# 165         21005  Tullamarine - Broadmeadows        PHN201
# 176         21301                    Brimbank        PHN201
# 177         21302                 Hobsons Bay        PHN201
# 178         21303                 Maribyrnong        PHN201
# 179         21304      Melton - Bacchus Marsh        PHN201
# ...

# %%
SA3_in_region = nwmphn['SA3_CODE_2016'].to_list()

# %%
SA3 = []
for item in SA3_in_region:
    SA3.append(str(item))

# %%
vemd_nwm = vemd_dec[vemd_dec['SA3_CODE'].isin(SA3)]

# %%
vemd_nwm
# Out:
#          Fin_Yr MonthName                 Arrival_Time  campus_code  \
# 80      2020/21      July          Weekday_Sociable_PM         1450
# 81      2020/21      July          Weekday_Sociable_PM         1450
# 84      2020/21      July          Weekday_Sociable_PM         1450
# 85      2020/21      July  Weekday_Unsociable_Early_AM         1450
# 86      2020/21      July  Weekday_Unsociable_Early_AM         1450
# ...         ...       ...                          ...          ...
# 792936  2020/21  November            Saturday_Early_AM         1021
# 792939  2020/21    August           Saturday_After_Hrs         1334
# 792941  2020/21    August            Weekday_BusHrs_AM         1334
# 792942  2020/21    August                    Sunday_AM         1334
# 792943  2020/21    August   Weekday_Unsociable_Late_PM         1334
#
#         did_not_wait  LOS_in_ED Trt_in_time  Time_to_treatment  \
# 80      Did not wait        176         NaN                NaN
# ...

# %%
vemd = pd.merge(vemd_nwm, nwmphn, )

# %%
vaed_nov = pd.read_csv('C:/Users/Emma.Zhang/OneDrive - Melbourne Primary Care Network/Documents/Needs Assessment/AOD/PHN_2021_Nov/PHN_VAED2021_Nov_20201217.txt', engine = 'python', delimiter='\t')

# %%
pd.set_option('display.max_columns', 500)
vaed_nov
# Out:
#         UniqueID       FY  CAMPUS Care_Type TenYearAgeGroups EMNL  \
# 0       44001931  2020/21    1121         4            70-79    L
# 1       44001932  2020/21    1121         4            60-69    E
# 2       44001933  2020/21    1121         4              80+    E
# 3       44001934  2020/21    1121         4            40-49    E
# 4       44001935  2020/21    1121         4            50-59    E
# ...          ...      ...     ...       ...              ...  ...
# 735517  45130251  2020/21    2060         4            40-49    L
# 735518  45130254  2020/21    2060         4            40-49    L
# 735519  45130255  2020/21    2060         4            30-39    L
# 735520  45130258  2020/21    2060         4            10-19    L
# 735521  45130260  2020/21    2060         4            30-39    M
#
#           Int_Duration_Stay  ADMBARTH  READMREH  SEPBARTH  ADMFIM  IMPAIR  \
# 0         Intended same day       NaN       NaN       NaN     NaN     NaN
# ...

# %% [markdown]
# #### Outcomes and priorities

# %% [markdown]
# #### Appendix
